# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eigh
from scipy.sparse import eye as speye
import nbimporter
from CDFQA_class import CDFQA

# Initialize the CDFQA object
cdfqa = CDFQA()

# Initialization
N = 6
J = np.complex128(-1)  # Ensure J is complex
hz = np.complex128(-0.4)  # Complex value for hz
hx = np.complex128(0)  # Complex value for hx
perBC = 1  # Periodic boundary conditions
CD = ['k', "#0072BD", "#D95319", "#7E2F8E", 'g', 'c', 'y']
FalqonCD = 0  # 0 for original FALQON
Colorcount = 2
alpha = 1
beta = 1
gamma = 1

# HP = np.zeros((2**N, 2**N), dtype=np.complex128);
# HM = np.zeros((2**N, 2**N), dtype=np.complex128);
# HCD0 = np.zeros((2**N, 2**N), dtype=np.complex128);
# HCD = np.zeros((2**N, 2**N), dtype=np.complex128);
# HCD1 = np.zeros((2**N, 2**N), dtype=np.complex128);
# HCD2 = np.zeros((2**N, 2**N), dtype=np.complex128);


# Building the Hamiltonians as complex matrices
HP = (cdfqa.ham_nn(N, 3, 3, J, perBC).astype(np.complex128) + 
      cdfqa.ham_onsite(N, 3, hz).astype(np.complex128) + 
      cdfqa.ham_onsite(N, 1, hx).astype(np.complex128))

# Eigen decomposition (equivalent to eig in MATLAB)
D, EV = eigh(HP)



# Define other Hamiltonians (ensuring they are complex)
HM = cdfqa.ham_onsite(N, 1, 1).astype(np.complex128)  # Ensure HM is complex
HCD0 = speye(2**N, dtype=np.complex128)  # Sparse identity matrix as complex
HCD = cdfqa.ham_onsite(N, 2, 1).astype(np.complex128)  # Ensure HCD is complex
HCD1 = cdfqa.ham_nn(N, 2, 3, 1, perBC).astype(np.complex128)  # Ensure HCD1 is complex
HCD2 = cdfqa.ham_nn(N, 2, 1, 1, perBC).astype(np.complex128)  # Ensure HCD2 is complex

# Initial state (normalized vector) as complex
psi_initial = np.ones(2**N, dtype=np.complex128) / np.sqrt(2**N)

# Circuit parameters
Layers = 200
dt = 0.01

# Running the energy vs circuit depth calculations
EN0, B0, G0 = cdfqa.cdfqa_energy_vs_cir_depth(N, HP, HM, HCD0, psi_initial, Layers, dt)
EN, B, G = cdfqa.cdfqa_energy_vs_cir_depth(N, HP, HM, HCD, psi_initial, Layers, dt)
EN1, B1, G1 = cdfqa.cdfqa_energy_vs_cir_depth(N, HP, HM, HCD1, psi_initial, Layers, dt)
EN2, B2, G2 = cdfqa.cdfqa_energy_vs_cir_depth(N, HP, HM, HCD2, psi_initial, Layers, dt)

# Plotting the results
plt.plot(range(1, Layers + 1), (np.real(EN0) - D[0]) / N, '-o', color=CD[FalqonCD], linewidth=2, label='EN0')
plt.plot(range(1, Layers + 1), (np.real(EN) - D[0]) / N, '-o', color=CD[FalqonCD + 1], linewidth=2, label='EN')
plt.plot(range(1, Layers + 1), (np.real(EN1) - D[0]) / N, '-o', color=CD[FalqonCD + 2], linewidth=2, label='EN1')
plt.plot(range(1, Layers + 1), (np.real(EN2) - D[0]) / N, '-o', color=CD[FalqonCD + 3], linewidth=2, label='EN2')

# Show the plot
plt.legend()
plt.xlabel('Layers')
plt.ylabel('Energy per spin')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[15], line 45
#      43 HM = cdfqa.ham_onsite(N, 1, 1).astype(np.complex128)  # Ensure HM is complex
#      44 HCD0 = speye(2**N, dtype=np.complex128)  # Sparse identity matrix as complex
# ---> 45 HCD = cdfqa.ham_onsite(N, 2, 1).astype(np.complex128)  # Ensure HCD is complex
#      46 HCD1 = cdfqa.ham_nn(N, 2, 3, 1, perBC).astype(np.complex128)  # Ensure HCD1 is complex
#      47 HCD2 = cdfqa.ham_nn(N, 2, 1, 1, perBC).astype(np.complex128)  # Ensure HCD2 is complex
#
# File ~/Documents/GitHub/CDFQA/CDFQA_class.ipynb:72, in ham_onsite(self, N, spin1, couplingNN)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "0b8cee20-62cd-4b8f-8f75-bce42cf59e9a",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "from scipy.sparse import kron, eye, csr_matrix\n",
#      12     "from scipy.linalg import expm\n",
#      13     "\n",
#      14     "\n",
#      15     "class CDFQA:\n",
#      16     "    def __init__(self):\n",
#      17     "        pass\n",
#      18     "\n",
#      19     "    def fast_expm(self, H, convergence_criteria=1e-6, non_zero_tol=1e-14):\n",
#      20     "        \"\"\"\n",
#      21     "        Fast matrix exponential for sparse or dense matrices.\n",
#      22     "        This method is adapted from the fastExpm function in MATLAB.\n",
#      23     "        \"\"\"\n",
#      24     "        P = expm(H)  # Using scipy's matrix exponential function\n",
#      25     "        P[np.abs(P) < non_zero_tol] = 0  # Eliminate small elements\n",
#      26     "        return P\n",
#      27     "\n",
#      28     "    def ham_nn(self, N, spin1, spin2, couplingNN, perBC):\n",
#      29     "        \"\"\"\n",
#      30     "        Generates the Nearest Neighbor (NN) Hamiltonian.\n",
#      31     "        \"\"\"\n",
#      32     "        def get_spin_matrix(spin):\n",
#      33     "            if spin == 0:\n",
#      34     "                return np.eye(2)\n",
#      35     "            elif spin == 1:\n",
#      36     "                return np.array([[0, 1], [1, 0]])  # Pauli-X\n",
#      37     "            elif spin == 2:\n",
#      38     "                return np.array([[0, -1j], [1j, 0]])  # Pauli-Y\n",
#      39     "            else:\n",
#      40     "                return np.array([[1, 0], [0, -1]])  # Pauli-Z\n",
#      41     "\n",
#      42     "        s11 = get_spin_matrix(spin1)\n",
#      43     "        s22 = get_spin_matrix(spin2)\n",
#      44     "        s1 = csr_matrix(s11)\n",
#      45     "        s2 = csr_matrix(s22)\n",
#      46     "\n",
#      47     "        H = csr_matrix((2**N, 2**N))  # Initialize the sparse Hamiltonian\n",
#      48     "\n",
#      49     "        for i in range(N - 1):\n",
#      50     "            if i == 0:\n",
#      51     "                H += couplingNN * kron(kron(s1, s2), eye(2**(N-2)))\n",
#      52     "            elif i == N - 2:\n",
#      53     "                H += couplingNN * kron(eye(2**(N-2)), kron(s1, s2))\n",
#      54     "            else:\n",
#      55     "                H += couplingNN * kron(eye(2**i), kron(kron(s1, s2), eye(2**(N-2-i))))\n",
#      56     "        \n",
#      57     "        if perBC == 1:\n",
#      58     "            H += couplingNN * kron(kron(s2, eye(2**(N-2))), s1)\n",
#      59     "\n",
#      60     "        return H\n",
#      61     "\n",
#      62     "    def ham_onsite(self, N, spin1, couplingNN):\n",
#      63     "        \"\"\"\n",
#      64     "        Generates the Onsite Hamiltonian.\n",
#      65     "        \"\"\"\n",
#      66     "        def get_spin_matrix(spin):\n",
#      67     "            if spin == 0:\n",
#      68     "                return np.eye(2)\n",
#      69     "            elif spin == 1:\n",
#      70     "                return np.array([[0, 1], [1, 0]])  # Pauli-X\n",
#      71     "            elif spin == 2:\n",
# ---> 72     "                return np.array([[0, -1j], [1j, 0]])  # Pauli-Y\n",
#      73     "            else:\n",
#      74     "                return np.array([[1, 0], [0, -1]])  # Pauli-Z\n",
#      75     "\n",
#      76     "        s1 = get_spin_matrix(spin1)\n",
#      77     "        H = np.zeros((2**N, 2**N))  # Initialize the dense Hamiltonian\n",
#      78     "\n",
#      79     "        for i in range(N):\n",
#      80     "            if i == 0:\n",
#      81     "                H += np.kron(s1, np.eye(2**(N-1)))\n",
#      82     "            elif i == N - 1:\n",
#      83     "                H += np.kron(np.eye(2**(N-1)), s1)\n",
#      84     "            else:\n",
#      85     "                H += np.kron(np.eye(2**i), np.kron(s1, np.eye(2**(N-i-1))))\n",
#      86     "\n",
#      87     "        return couplingNN * H\n",
#      88     "\n",
#      89     "    def cdfqa_energy_vs_cir_depth(self, N, HP, HM, HCD, psi_initial, Layers, dt):\n",
#      90     "        \"\"\"\n",
#      91     "        Computes energy vs circuit depth for the given system.\n",
#      92     "        \"\"\"\n",
#      93     "        EN = np.zeros(Layers)\n",
#      94     "        B = np.zeros(Layers)\n",
#      95     "        G = np.zeros(Layers)\n",
#      96     "        CM = HM @ HP - HP @ HM\n",
#      97     "        CMCD = HCD @ HP - HP @ HCD\n",
#      98     "\n",
#      99     "        psi = psi_initial\n",
#     100     "        EN[0] = np.conjugate(psi).T @ HP @ psi\n",
#     101     "        B[0] = 0\n",
#     102     "        G[0] = 0\n",
#     103     "\n",
#     104     "        for i in range(1, Layers):\n",
#     105     "            psi = self.fast_expm(-1j * dt * G[i-1] * HCD) @ (\n",
#     106     "                self.fast_expm(-1j * dt * B[i-1] * HM) @ (\n",
#     107     "                    self.fast_expm(-1j * dt * HP) @ psi\n",
#     108     "                )\n",
#     109     "            )\n",
#     110     "\n",
#     111     "            B[i] = -1j * (np.conjugate(psi).T @ CM @ psi)\n",
#     112     "            G[i] = -1j * (np.conjugate(psi).T @ CMCD @ psi)\n",
#     113     "            EN[i] = np.conjugate(psi).T @ HP @ psi\n",
#     114     "\n",
#     115     "        return EN, B, G\n"
#     116    ]
#     117   }
#     118  ],
#     119  "metadata": {
#     120   "kernelspec": {
#     121    "display_name": "Python 3 (ipykernel)",
#     122    "language": "python",
#     123    "name": "python3"
#     124   },
#     125   "language_info": {
#     126    "codemirror_mode": {
#     127     "name": "ipython",
#     128     "version": 3
#     129    },
#     130    "file_extension": ".py",
#     131    "mimetype": "text/x-python",
#     132    "name": "python",
#     133    "nbconvert_exporter": "python",
#     134    "pygments_lexer": "ipython3",
#     135    "version": "3.9.6"
#     136   }
#     137  },
#     138  "nbformat": 4,
#     139  "nbformat_minor": 5
#     140 }
#
# UFuncTypeError: Cannot cast ufunc 'add' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
